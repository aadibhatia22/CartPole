# %% [markdown]
# # This is a sample Jupyter Notebook
#
# Below is an example of a code cell.
# Put your cursor into the cell and press Shift+Enter to execute it and select the next one, or click 'Run Cell' button.
#
# Press Double Shift to search everywhere for classes, files, tool windows, actions, and settings.
#
# To learn more about Jupyter Notebooks in PyCharm, see [help](https://www.jetbrains.com/help/pycharm/ipython-notebook-support.html).
# For an overview of PyCharm, go to Help -> Learn IDE features or refer to [our documentation](https://www.jetbrains.com/help/pycharm/getting-started.html).

# %%
import numpy as np
from models.NeuralNetwork import NeuralNetwork
nn = NeuralNetwork(
      learning_rate=0.01,
      discount_factor=0.99,
      architecture=np.array([4, 8, 4, 1]),
      random_number1 = -1,
    random_number2 = 1
)

nn.print_network()
x = np.array([1, 2, 3, 4])
nn.print_prediction_steps(x)
# Out:
# ==================================================
# NEURAL NETWORK STRUCTURE
# ==================================================
#
# Layer 0 (INPUT)
#  Neurons: 4
#
# Layer 1 (HIDDEN)
#  Neurons: 8
#  Weights shape: (8, 4)
#  Weights:
# [[ 0.205  0.003  0.024 -0.088]
#  [ 0.709 -0.167  0.373  0.666]
#  [-0.9    0.045 -0.92  -0.477]
#  [-0.176 -0.855  0.509  0.535]
#  [-0.981  0.179 -0.242  0.693]
#  [ 0.525 -0.425 -0.322  0.876]
#  [-0.938 -0.696  0.966 -0.449]
#  [-0.047  0.167 -0.569  0.872]]
#  Bias shape: (8, 1)
#  Bias:
# [[ 0.999]
#  [ 0.795]
#  [-0.05 ]
#  [ 0.787]
#  [-0.913]
#  [ 0.98 ]
#  [ 0.169]
#  [-0.763]]
# --------------------------------------------------
#
# Layer 2 (HIDDEN)
#  Neurons: 4
#  Weights shape: (4, 8)
#  Weights:
# [[-0.864 -0.17  -0.112 -0.533  0.178  0.099  0.376 -0.699]
#  [-0.229 -0.449 -0.72  -0.009  0.721 -0.266 -0.954 -0.52 ]
#  [-0.82   0.942  0.193  0.384  0.761 -0.439 -0.823 -0.78 ]
#  [-0.285  0.715 -0.755 -0.858 -0.999 -0.239 -0.122  0.546]]
#  Bias shape: (4, 1)
#  Bias:
# [[ 0.658]
#  [-0.206]
#  [ 0.407]
#  [ 0.09 ]]
# --------------------------------------------------
#
# Layer 3 (OUTPUT)
#  Neurons: 1
#  Weights shape: (1, 4)
#  Weights:
# [[ 0.716 -0.307  0.704  0.906]]
#  Bias shape: (1, 1)
#  Bias:
# [[-0.385]]
# --------------------------------------------------
# ==================================================
#
#
# ============================================================
# FORWARD PASS
# ============================================================
# Architecture: [4 8 4 1]
# Starting input shape: (4, 1)
# Starting input:
# [[1]
#  [2]
#  [3]
#  [4]]
#
# ------------------------------------------------------------
# Layer 1 (HIDDEN)
# Calculating: weight[1] @ input + bias[1]
# weight[1] shape: (8, 4)
# input shape:     (4, 1)
# bias[1] shape:   (8, 1)
# Result before activation shape: (8, 1)
# Result before activation:
# [[ 0.93 ]
#  [ 4.954]
#  [-5.525]
#  [ 2.569]
#  [ 0.508]
#  [ 3.193]
#  [-1.059]
#  [ 1.305]]
# Activation: ReLU, max(0, value)
# Result after activation:
# [[0.93 ]
#  [4.954]
#  [0.   ]
#  [2.569]
#  [0.508]
#  [3.193]
#  [0.   ]
#  [1.305]]
#
# ------------------------------------------------------------
# Layer 2 (HIDDEN)
# Calculating: weight[2] @ input + bias[2]
# weight[2] shape: (4, 8)
# input shape:     (8, 1)
# bias[2] shape:   (4, 1)
# Result before activation shape: (4, 1)
# Result before activation:
# [[-2.864]
#  [-3.826]
#  [ 3.265]
#  [ 0.606]]
# Activation: ReLU, max(0, value)
# Result after activation:
# [[0.   ]
#  [0.   ]
#  [3.265]
#  [0.606]]
#
# ------------------------------------------------------------
# Layer 3 (OUTPUT)
# Calculating: weight[3] @ input + bias[3]
# weight[3] shape: (1, 4)
# input shape:     (4, 1)
# bias[3] shape:   (1, 1)
# Result before activation shape: (1, 1)
# Result before activation:
# [[2.462]]
# Activation: Sigmoid, 1 / (1 + exp(-value))
# Result after activation:
# [[0.921]]
#
# ============================================================
# FINAL OUTPUT
# ============================================================
# [[0.921]]
# ============================================================
# array([[0.92143492]])
